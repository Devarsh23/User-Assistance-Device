# %%
# USAGE
# python extract_embeddings.py --dataset dataset --embeddings output/embeddings.pickle \
#	--detector face_detection_model --embedding-model openface_nn4.small2.v1.t7

# import the necessary packages
from imutils import paths
import numpy as np
import imutils
import pickle
import cv2
import os



# load our serialized face detector from disk
print("[INFO] loading face detector...")
protoPath = os.path.sep.join(["face_detection_model", "deploy.prototxt"])
modelPath = os.path.sep.join(["face_detection_model","res10_300x300_ssd_iter_140000.caffemodel"])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)

# load our serialized face embedding model from disk
print("[INFO] loading face recognizer...")
embedder = cv2.dnn.readNetFromTorch("openface_nn4.small2.v1.t7")

# grab the paths to the input images in our dataset
print("[INFO] quantifying faces...")
imagePaths = list(paths.list_images("dataset"))
#print(imagePaths)

# initialize our lists of extracted facial embeddings and
# corresponding people names
knownEmbeddings = []
knownNames = []

# initialize the total number of faces processed
total = 0

# loop over the image paths
for (i, imagePath) in enumerate(imagePaths):
	# extract the person name from the image path
	print("[INFO] processing image {}/{}".format(i + 1,
		len(imagePaths)))
	name = imagePath.split(os.path.sep)[-2]
	print(name)

	# load the image, resize it to have a width of 600 pixels (while
	# maintaining the aspect ratio), and then grab the image
	# dimensions
	image = cv2.imread(imagePath)
	image = imutils.resize(image, width=600)
	(h, w) = image.shape[:2]

	# construct a blob from the image
	imageBlob = cv2.dnn.blobFromImage(
		cv2.resize(image, (300, 300)), 1.0, (300, 300),
		(104.0, 177.0, 123.0), swapRB=False, crop=False)

	# apply OpenCV's deep learning-based face detector to localize
	# faces in the input image
	detector.setInput(imageBlob)
	detections = detector.forward()

	# ensure at least one face was found
	if len(detections) > 0:
		# we're making the assumption that each image has only ONE
		# face, so find the bounding box with the largest probability
		i = np.argmax(detections[0, 0, :, 2])
		confidence = detections[0, 0, i, 2]

		# ensure that the detection with the largest probability also
		# means our minimum probability test (thus helping filter out
		# weak detections)
		if confidence > 0.2:
			# compute the (x, y)-coordinates of the bounding box for
			# the face
			box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
			(startX, startY, endX, endY) = box.astype("int")

			# extract the face ROI and grab the ROI dimensions
			face = image[startY:endY, startX:endX]
			(fH, fW) = face.shape[:2]

			# ensure the face width and height are sufficiently large
			if fW < 20 or fH < 20:
				continue

			# construct a blob for the face ROI, then pass the blob
			# through our face embedding model to obtain the 128-d
			# quantification of the face
			faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255,
				(96, 96), (0, 0, 0), swapRB=True, crop=False)
			embedder.setInput(faceBlob)
			vec = embedder.forward()

			# add the name of the person + corresponding face
			# embedding to their respective lists
			knownNames.append(name)
			knownEmbeddings.append(vec.flatten())
			total += 1

# dump the facial embeddings + names to disk
print("[INFO] serializing {} encodings...".format(total))
data = {"embeddings": knownEmbeddings, "names": knownNames}
f = open("output/embeddings.pickle", "wb")
f.write(pickle.dumps(data))
f.close()
# Out:
# [INFO] loading face detector...
# [INFO] loading face recognizer...
# [INFO] quantifying faces...
# [INFO] processing image 1/330
# Jainish
# [INFO] processing image 2/330
# Jainish
# [INFO] processing image 3/330
# Jainish
# [INFO] processing image 4/330
# Jainish
# [INFO] processing image 5/330
# Jainish
# [INFO] processing image 85/330
# Jainish
# [INFO] processing image 86/330
# Jainish
# [INFO] processing image 87/330
# Jainish
# [INFO] processing image 88/330
# Jainish
# [INFO] processing image 89/330
# Jainish
# [INFO] processing image 90/330
# Jainish
# [INFO] processing image 91/330
# Jainish
# [INFO] processing image 92/330
# Jainish
# [INFO] processing image 93/330
# Jainish
# [INFO] processing image 94/330
# Jainish
# [INFO] processing image 95/330
# Jainish
# [INFO] processing image 96/330
# Jainish
# [INFO] processing image 97/330
# Jainish
# [INFO] processing image 98/330
# Jainish
# [INFO] processing image 99/330
# Jainish
# [INFO] processing image 100/330
# Jainish
# [INFO] processing image 101/330
# unknown
# [INFO] processing image 102/330
# unknown
# [INFO] processing image 103/330
# unknown
# [INFO] processing image 104/330
# unknown
# [INFO] processing image 105/330
# unknown
# [INFO] processing image 106/330
# unknown
# [INFO] processing image 107/330
# unknown
# [INFO] processing image 108/330
# unknown
# [INFO] processing image 109/330
# unknown
# [INFO] processing image 110/330
# unknown
# [INFO] processing image 111/330
# unknown
# [INFO] processing image 112/330
# unknown
# [INFO] processing image 113/330
# unknown
# [INFO] processing image 114/330
# unknown
# [INFO] processing image 115/330
# unknown
# [INFO] processing image 116/330
# unknown
# [INFO] processing image 117/330
# unknown
# [INFO] processing image 118/330
# unknown
# [INFO] processing image 119/330
# unknown
# [INFO] processing image 120/330
# unknown
# [INFO] processing image 121/330
# unknown
# [INFO] processing image 122/330
# unknown
# [INFO] processing image 123/330
# unknown
# [INFO] processing image 124/330
# unknown
# [INFO] processing image 125/330
# unknown
# [INFO] processing image 126/330
# unknown
# [INFO] processing image 127/330
# unknown
# [INFO] processing image 128/330
# unknown
# [INFO] processing image 129/330
# unknown
# [INFO] processing image 130/330
# unknown
# [INFO] processing image 131/330
# unknown
# [INFO] processing image 132/330
# unknown
# [INFO] processing image 133/330
# unknown
# [INFO] processing image 134/330
# unknown
# [INFO] processing image 135/330
# unknown
# [INFO] processing image 136/330
# unknown
# [INFO] processing image 137/330
# unknown
# [INFO] processing image 138/330
# unknown
# [INFO] processing image 139/330
# unknown
# [INFO] processing image 140/330
# unknown
# [INFO] processing image 141/330
# unknown
# [INFO] processing image 142/330
# unknown
# [INFO] processing image 143/330
# unknown
# [INFO] processing image 144/330
# unknown
# [INFO] processing image 145/330
# unknown
# [INFO] processing image 146/330
# unknown
# [INFO] processing image 147/330
# unknown
# [INFO] processing image 148/330
# unknown
# [INFO] processing image 149/330
# unknown
# [INFO] processing image 150/330
# unknown
# [INFO] processing image 151/330
# unknown
# [INFO] processing image 152/330
# unknown
# [INFO] processing image 153/330
# unknown
# [INFO] processing image 154/330
# unknown
# [INFO] processing image 155/330
# unknown
# [INFO] processing image 156/330
# unknown
# [INFO] processing image 157/330
# unknown
# [INFO] processing image 158/330
# unknown
# [INFO] processing image 159/330
# unknown
# [INFO] processing image 160/330
# unknown
# [INFO] processing image 161/330
# unknown
# [INFO] processing image 162/330
# unknown
# [INFO] processing image 163/330
# unknown
# [INFO] processing image 164/330
# unknown
# [INFO] processing image 165/330
# unknown
# [INFO] processing image 166/330
# unknown
# [INFO] processing image 167/330
# unknown
# [INFO] processing image 168/330
# unknown
# [INFO] processing image 169/330
# unknown
# [INFO] processing image 170/330
# unknown
# [INFO] processing image 171/330
# unknown
# [INFO] processing image 172/330
# unknown
# [INFO] processing image 173/330
# unknown
# [INFO] processing image 174/330
# unknown
# [INFO] processing image 175/330
# unknown
# [INFO] processing image 176/330
# unknown
# [INFO] processing image 177/330
# unknown
# [INFO] processing image 178/330
# unknown
# [INFO] processing image 179/330
# unknown
# [INFO] processing image 180/330
# unknown
# [INFO] processing image 181/330
# unknown
# [INFO] processing image 182/330
# unknown
# [INFO] processing image 183/330
# unknown
# [INFO] processing image 184/330
# unknown
# [INFO] processing image 185/330
# unknown
# [INFO] processing image 186/330
# unknown
# [INFO] processing image 187/330
# unknown
# [INFO] processing image 188/330
# unknown
# [INFO] processing image 189/330
# unknown
# [INFO] processing image 190/330
# unknown
# [INFO] processing image 191/330
# unknown
# [INFO] processing image 192/330
# unknown
# [INFO] processing image 193/330
# unknown
# [INFO] processing image 194/330
# unknown
# [INFO] processing image 195/330
# unknown
# [INFO] processing image 196/330
# unknown
# [INFO] processing image 197/330
# unknown
# [INFO] processing image 198/330
# unknown
# [INFO] processing image 199/330
# unknown
# [INFO] processing image 200/330
# unknown
# [INFO] processing image 201/330
# unknown
# [INFO] processing image 202/330
# unknown
# [INFO] processing image 203/330
# unknown
# [INFO] processing image 204/330
# unknown
# [INFO] processing image 205/330
# unknown
# [INFO] processing image 206/330
# unknown
# [INFO] processing image 207/330
# unknown
# [INFO] processing image 208/330
# unknown
# [INFO] processing image 209/330
# unknown
# [INFO] processing image 210/330
# unknown
# [INFO] processing image 211/330
# unknown
# [INFO] processing image 212/330
# unknown
# [INFO] processing image 213/330
# unknown
# [INFO] processing image 214/330
# unknown
# [INFO] processing image 215/330
# unknown
# [INFO] processing image 216/330
# unknown
# [INFO] processing image 217/330
# unknown
# [INFO] processing image 218/330
# unknown
# [INFO] processing image 219/330
# unknown
# [INFO] processing image 220/330
# unknown
# [INFO] processing image 221/330
# unknown
# [INFO] processing image 222/330
# unknown
# [INFO] processing image 223/330
# unknown
# [INFO] processing image 224/330
# unknown
# [INFO] processing image 225/330
# unknown
# [INFO] processing image 226/330
# unknown
# [INFO] processing image 227/330
# unknown
# [INFO] processing image 228/330
# unknown
# [INFO] processing image 229/330
# unknown
# [INFO] processing image 230/330
# unknown
# [INFO] processing image 231/330
# unknown
# [INFO] processing image 232/330
# unknown
# [INFO] processing image 233/330
# unknown
# [INFO] processing image 234/330
# unknown
# [INFO] processing image 235/330
# unknown
# [INFO] processing image 236/330
# unknown
# [INFO] processing image 237/330
# unknown
# [INFO] processing image 238/330
# unknown
# [INFO] processing image 239/330
# unknown
# [INFO] processing image 240/330
# unknown
# [INFO] processing image 241/330
# unknown
# [INFO] processing image 242/330
# unknown
# [INFO] processing image 243/330
# unknown
# [INFO] processing image 244/330
# unknown
# [INFO] processing image 245/330
# unknown
# [INFO] processing image 246/330
# unknown
# [INFO] processing image 247/330
# unknown
# [INFO] processing image 248/330
# unknown
# [INFO] processing image 249/330
# unknown
# [INFO] processing image 250/330
# unknown
# [INFO] processing image 251/330
# unknown
# [INFO] processing image 252/330
# unknown
# [INFO] processing image 253/330
# unknown
# [INFO] processing image 254/330
# unknown
# [INFO] processing image 255/330
# unknown
# [INFO] processing image 256/330
# unknown
# [INFO] processing image 257/330
# unknown
# [INFO] processing image 258/330
# unknown
# [INFO] processing image 259/330
# unknown
# [INFO] processing image 260/330
# unknown
# [INFO] processing image 261/330
# unknown
# [INFO] processing image 262/330
# unknown
# [INFO] processing image 263/330
# unknown
# [INFO] processing image 264/330
# unknown
# [INFO] processing image 265/330
# unknown
# [INFO] processing image 266/330
# unknown
# [INFO] processing image 267/330
# unknown
# [INFO] processing image 268/330
# unknown
# [INFO] processing image 269/330
# unknown
# [INFO] processing image 270/330
# unknown
# [INFO] processing image 271/330
# unknown
# [INFO] processing image 272/330
# unknown
# [INFO] processing image 273/330
# unknown
# [INFO] processing image 274/330
# unknown
# [INFO] processing image 275/330
# unknown
# [INFO] processing image 276/330
# unknown
# [INFO] processing image 277/330
# unknown
# [INFO] processing image 278/330
# unknown
# [INFO] processing image 279/330
# unknown
# [INFO] processing image 280/330
# unknown
# [INFO] processing image 281/330
# unknown
# [INFO] processing image 282/330
# unknown
# [INFO] processing image 283/330
# unknown
# [INFO] processing image 284/330
# unknown
# [INFO] processing image 285/330
# unknown
# [INFO] processing image 286/330
# unknown
# [INFO] processing image 287/330
# unknown
# [INFO] processing image 288/330
# unknown
# [INFO] processing image 289/330
# unknown
# [INFO] processing image 290/330
# unknown
# [INFO] processing image 291/330
# unknown
# [INFO] processing image 292/330
# unknown
# [INFO] processing image 293/330
# unknown
# [INFO] processing image 294/330
# unknown
# [INFO] processing image 295/330
# unknown
# [INFO] processing image 296/330
# unknown
# [INFO] processing image 297/330
# unknown
# [INFO] processing image 298/330
# unknown
# [INFO] processing image 299/330
# unknown
# [INFO] processing image 300/330
# unknown
# [INFO] processing image 301/330
# unknown
# [INFO] processing image 302/330
# unknown
# [INFO] processing image 303/330
# unknown
# [INFO] processing image 304/330
# unknown
# [INFO] processing image 305/330
# unknown
# [INFO] processing image 306/330
# unknown
# [INFO] processing image 307/330
# unknown
# [INFO] processing image 308/330
# unknown
# [INFO] processing image 309/330
# unknown
# [INFO] processing image 310/330
# unknown
# [INFO] processing image 311/330
# unknown
# [INFO] processing image 312/330
# unknown
# [INFO] processing image 313/330
# unknown
# [INFO] processing image 314/330
# unknown
# [INFO] processing image 315/330
# unknown
# [INFO] processing image 316/330
# unknown
# [INFO] processing image 317/330
# unknown
# [INFO] processing image 318/330
# unknown
# [INFO] processing image 319/330
# unknown
# [INFO] processing image 320/330
# unknown
# [INFO] processing image 321/330
# unknown
# [INFO] processing image 322/330
# unknown
# [INFO] processing image 323/330
# unknown
# [INFO] processing image 324/330
# unknown
# [INFO] processing image 325/330
# unknown
# [INFO] processing image 326/330
# unknown
# [INFO] processing image 327/330
# unknown
# [INFO] processing image 328/330
# unknown
# [INFO] processing image 329/330
# unknown
# [INFO] processing image 330/330
# unknown
# [INFO] serializing 330 encodings...
